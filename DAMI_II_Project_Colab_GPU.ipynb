# %%
! pip install codecarbon
# Out:
# Requirement already satisfied: codecarbon in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: arrow in /usr/local/lib/python3.10/dist-packages (from codecarbon) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from codecarbon) (1.5.3)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.10/dist-packages (from codecarbon) (11.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from codecarbon) (2.31.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (from codecarbon) (0.18.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from codecarbon) (8.1.7)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from codecarbon) (0.19.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from arrow->codecarbon) (2.8.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow->codecarbon) (2.8.19.14)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.16.0)

# %%
from numpy import mean
from numpy import std
import keras
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.layers import BatchNormalization
from keras import backend as K
from keras import layers
from codecarbon import track_emissions
import matplotlib.pyplot as plt
import csv

# %%
print(K.backend())
# Out:
# tensorflow

# %%
# cnn model with batch normalization for mnist
# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY

# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm

# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.01, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=3):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=42)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		history = model.fit(trainX, trainY, epochs=3, batch_size=32, validation_data=(testX, testY), verbose=2)
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=2)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories

# plot diagnostic learning curves
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		plt.tight_layout()
		plt.subplot(2, 1, 1)
		plt.grid()
		plt.title('Cross Entropy Loss')
		plt.plot(histories[i].history['loss'], color='darkcyan', label='train')
		plt.plot(histories[i].history['val_loss'], color='violet', label='test')
		handles, labels = plt.gca().get_legend_handles_labels()
		by_label = dict(zip(labels, handles))
		plt.legend(by_label.values(), by_label.keys(),loc="upper right")

		# plot accuracy
		plt.subplot(2, 1, 2)
		plt.grid()
		plt.title('Classification Accuracy')
		plt.plot(histories[i].history['accuracy'], color='darkcyan', label='train')
		plt.plot(histories[i].history['val_accuracy'], color='violet', label='test')
		handles, labels = plt.gca().get_legend_handles_labels()
		by_label = dict(zip(labels, handles))
		plt.legend(by_label.values(), by_label.keys(),loc="lower right")
	plt.show()

# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	plt.boxplot(scores)
	plt.show()

# save model performance to file
def save_performance_to_csv(scores):
	# print summary
	with open ("accuracy_scores_gpu_colab.csv",'a') as f:
		data = ["DAMI II Project Colab GPU TF", round(mean(scores)*100, 3), round(std(scores)*100, 3)]
		writer = csv.writer(f)
		writer.writerow(data)

# run the test harness for evaluating a model

@track_emissions(offline=True, country_iso_code="ITA", project_name = "DAMI II Project Colab GPU TF")
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)
  # print accuracy scores to csv
	save_performance_to_csv(scores)


# run the test harness three times
i=0
while i<3:
	run_test_harness()
	i+=1
# Out:
# [codecarbon INFO @ 14:03:47] offline tracker init
# [codecarbon INFO @ 14:03:47] [setup] RAM Tracking...
# [codecarbon INFO @ 14:03:47] [setup] GPU Tracking...
# [codecarbon INFO @ 14:03:47] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 14:03:47] [setup] CPU Tracking...
# [codecarbon WARNING @ 14:03:47] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 14:03:49] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 14:03:49] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 14:03:49] >>> Tracker's metadata:
# [codecarbon INFO @ 14:03:49]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# [codecarbon INFO @ 14:03:49]   Python version: 3.10.12
# [codecarbon INFO @ 14:03:49]   CodeCarbon version: 2.3.2
# [codecarbon INFO @ 14:03:49]   Available RAM : 12.675 GB
# [codecarbon INFO @ 14:03:49]   CPU count: 2
# [codecarbon INFO @ 14:03:49]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 14:03:49]   GPU count: 1
# [codecarbon INFO @ 14:03:49]   GPU model: 1 x Tesla T4
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/3
# [codecarbon INFO @ 14:04:04] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:04:04] Energy consumed for all GPUs : 0.000110 kWh. Total GPU Power : 26.33522648444849 W
# [codecarbon INFO @ 14:04:04] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:04:04] 0.000307 kWh of electricity used since the beginning.
# 1250/1250 - 18s - loss: 0.1518 - accuracy: 0.9551 - val_loss: 0.0727 - val_accuracy: 0.9786 - 18s/epoch - 15ms/step
# Epoch 2/3
# 1250/1250 - 5s - loss: 0.0590 - accuracy: 0.9821 - val_loss: 0.0616 - val_accuracy: 0.9812 - 5s/epoch - 4ms/step
# Epoch 3/3
# [codecarbon INFO @ 14:04:19] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:04:19] Energy consumed for all GPUs : 0.000234 kWh. Total GPU Power : 29.737292621715696 W
# [codecarbon INFO @ 14:04:19] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:04:19] 0.000628 kWh of electricity used since the beginning.
# 1250/1250 - 6s - loss: 0.0352 - accuracy: 0.9894 - val_loss: 0.0556 - val_accuracy: 0.9832 - 6s/epoch - 5ms/step
# 625/625 - 1s - loss: 0.0556 - accuracy: 0.9832 - 1s/epoch - 2ms/step
# > 98.320
# Epoch 1/3
# 1250/1250 - 6s - loss: 0.1451 - accuracy: 0.9557 - val_loss: 0.0776 - val_accuracy: 0.9764 - 6s/epoch - 5ms/step
# Epoch 2/3
# 1250/1250 - 6s - loss: 0.0520 - accuracy: 0.9837 - val_loss: 0.0630 - val_accuracy: 0.9805 - 6s/epoch - 4ms/step
# Epoch 3/3
# [codecarbon INFO @ 14:04:34] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:04:34] Energy consumed for all GPUs : 0.000358 kWh. Total GPU Power : 29.85603154396159 W
# [codecarbon INFO @ 14:04:34] Energy consumed for all CPUs : 0.000532 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:04:34] 0.000949 kWh of electricity used since the beginning.
# 1250/1250 - 5s - loss: 0.0325 - accuracy: 0.9903 - val_loss: 0.0574 - val_accuracy: 0.9826 - 5s/epoch - 4ms/step
# 625/625 - 1s - loss: 0.0574 - accuracy: 0.9826 - 1s/epoch - 2ms/step
# > 98.255
# Epoch 1/3
# 1250/1250 - 7s - loss: 0.1452 - accuracy: 0.9575 - val_loss: 0.0703 - val_accuracy: 0.9792 - 7s/epoch - 5ms/step
# Epoch 2/3
# [codecarbon INFO @ 14:04:49] Energy consumed for RAM : 0.000079 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:04:49] Energy consumed for all GPUs : 0.000486 kWh. Total GPU Power : 30.799761720076756 W
# [codecarbon INFO @ 14:04:49] Energy consumed for all CPUs : 0.000709 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:04:49] 0.001275 kWh of electricity used since the beginning.
# 1250/1250 - 5s - loss: 0.0531 - accuracy: 0.9844 - val_loss: 0.0635 - val_accuracy: 0.9806 - 5s/epoch - 4ms/step
# Epoch 3/3
# 1250/1250 - 5s - loss: 0.0303 - accuracy: 0.9913 - val_loss: 0.0566 - val_accuracy: 0.9822 - 5s/epoch - 4ms/step
# 625/625 - 2s - loss: 0.0566 - accuracy: 0.9822 - 2s/epoch - 3ms/step
# > 98.225
# Accuracy: mean=98.267 std=0.040, n=3
# [codecarbon INFO @ 14:04:59]
# Graceful stopping: collecting and writing information.
# Please wait a few seconds...
# [codecarbon INFO @ 14:04:59] Energy consumed for RAM : 0.000093 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:04:59] Energy consumed for all GPUs : 0.000574 kWh. Total GPU Power : 30.355348627409644 W
# [codecarbon INFO @ 14:04:59] Energy consumed for all CPUs : 0.000832 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:04:59] 0.001498 kWh of electricity used since the beginning.
# [codecarbon INFO @ 14:04:59] Done!
#
# [codecarbon INFO @ 14:04:59] offline tracker init
# [codecarbon INFO @ 14:04:59] [setup] RAM Tracking...
# [codecarbon INFO @ 14:04:59] [setup] GPU Tracking...
# [codecarbon INFO @ 14:04:59] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 14:04:59] [setup] CPU Tracking...
# [codecarbon WARNING @ 14:04:59] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 14:05:01] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 14:05:01] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 14:05:01] >>> Tracker's metadata:
# [codecarbon INFO @ 14:05:01]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# [codecarbon INFO @ 14:05:01]   Python version: 3.10.12
# [codecarbon INFO @ 14:05:01]   CodeCarbon version: 2.3.2
# [codecarbon INFO @ 14:05:01]   Available RAM : 12.675 GB
# [codecarbon INFO @ 14:05:01]   CPU count: 2
# [codecarbon INFO @ 14:05:01]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 14:05:01]   GPU count: 1
# [codecarbon INFO @ 14:05:01]   GPU model: 1 x Tesla T4
# Epoch 1/3
# 1250/1250 - 7s - loss: 0.1539 - accuracy: 0.9547 - val_loss: 0.0763 - val_accuracy: 0.9773 - 7s/epoch - 6ms/step
# Epoch 2/3
# 1250/1250 - 5s - loss: 0.0574 - accuracy: 0.9833 - val_loss: 0.0646 - val_accuracy: 0.9806 - 5s/epoch - 4ms/step
# Epoch 3/3
# [codecarbon INFO @ 14:05:16] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:05:16] Energy consumed for all GPUs : 0.000128 kWh. Total GPU Power : 30.610199937856446 W
# [codecarbon INFO @ 14:05:16] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:05:16] 0.000325 kWh of electricity used since the beginning.
# 1250/1250 - 5s - loss: 0.0355 - accuracy: 0.9897 - val_loss: 0.0557 - val_accuracy: 0.9833 - 5s/epoch - 4ms/step
# 625/625 - 1s - loss: 0.0557 - accuracy: 0.9833 - 1s/epoch - 2ms/step
# > 98.330
# Epoch 1/3
# 1250/1250 - 6s - loss: 0.1402 - accuracy: 0.9578 - val_loss: 0.0671 - val_accuracy: 0.9796 - 6s/epoch - 5ms/step
# Epoch 2/3
# [codecarbon INFO @ 14:05:31] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:05:31] Energy consumed for all GPUs : 0.000254 kWh. Total GPU Power : 30.44260030694504 W
# [codecarbon INFO @ 14:05:31] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:05:31] 0.000648 kWh of electricity used since the beginning.
# 1250/1250 - 7s - loss: 0.0532 - accuracy: 0.9839 - val_loss: 0.0600 - val_accuracy: 0.9834 - 7s/epoch - 5ms/step
# Epoch 3/3
# 1250/1250 - 5s - loss: 0.0319 - accuracy: 0.9900 - val_loss: 0.0576 - val_accuracy: 0.9833 - 5s/epoch - 4ms/step
# [codecarbon INFO @ 14:05:46] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:05:46] Energy consumed for all GPUs : 0.000382 kWh. Total GPU Power : 30.57297856394061 W
# [codecarbon INFO @ 14:05:46] Energy consumed for all CPUs : 0.000532 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:05:46] 0.000973 kWh of electricity used since the beginning.
# 625/625 - 2s - loss: 0.0576 - accuracy: 0.9833 - 2s/epoch - 3ms/step
# > 98.335
# Epoch 1/3
# 1250/1250 - 6s - loss: 0.1507 - accuracy: 0.9553 - val_loss: 0.0718 - val_accuracy: 0.9783 - 6s/epoch - 5ms/step
# Epoch 2/3
# [codecarbon INFO @ 14:06:01] Energy consumed for RAM : 0.000079 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:06:01] Energy consumed for all GPUs : 0.000510 kWh. Total GPU Power : 31.04338873232294 W
# [codecarbon INFO @ 14:06:01] Energy consumed for all CPUs : 0.000708 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:06:01] 0.001298 kWh of electricity used since the beginning.
# 1250/1250 - 6s - loss: 0.0579 - accuracy: 0.9829 - val_loss: 0.0605 - val_accuracy: 0.9814 - 6s/epoch - 5ms/step
# Epoch 3/3
# 1250/1250 - 5s - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.0521 - val_accuracy: 0.9843 - 5s/epoch - 4ms/step
# 625/625 - 2s - loss: 0.0521 - accuracy: 0.9843 - 2s/epoch - 2ms/step
# > 98.425
# Accuracy: mean=98.363 std=0.044, n=3
# [codecarbon INFO @ 14:06:13]
# Graceful stopping: collecting and writing information.
# Please wait a few seconds...
# [codecarbon INFO @ 14:06:13] Energy consumed for RAM : 0.000096 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:06:14] Energy consumed for all GPUs : 0.000617 kWh. Total GPU Power : 30.34244316109935 W
# [codecarbon INFO @ 14:06:14] Energy consumed for all CPUs : 0.000858 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:06:14] 0.001571 kWh of electricity used since the beginning.
# [codecarbon INFO @ 14:06:14] Done!
#
# [codecarbon INFO @ 14:06:14] offline tracker init
# [codecarbon INFO @ 14:06:14] [setup] RAM Tracking...
# [codecarbon INFO @ 14:06:14] [setup] GPU Tracking...
# [codecarbon INFO @ 14:06:14] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 14:06:14] [setup] CPU Tracking...
# [codecarbon WARNING @ 14:06:14] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 14:06:15] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 14:06:15] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 14:06:15] >>> Tracker's metadata:
# [codecarbon INFO @ 14:06:15]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# [codecarbon INFO @ 14:06:15]   Python version: 3.10.12
# [codecarbon INFO @ 14:06:15]   CodeCarbon version: 2.3.2
# [codecarbon INFO @ 14:06:15]   Available RAM : 12.675 GB
# [codecarbon INFO @ 14:06:15]   CPU count: 2
# [codecarbon INFO @ 14:06:15]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 14:06:15]   GPU count: 1
# [codecarbon INFO @ 14:06:15]   GPU model: 1 x Tesla T4
# Epoch 1/3
# 1250/1250 - 6s - loss: 0.1573 - accuracy: 0.9539 - val_loss: 0.0760 - val_accuracy: 0.9790 - 6s/epoch - 5ms/step
# Epoch 2/3
# 1250/1250 - 5s - loss: 0.0604 - accuracy: 0.9815 - val_loss: 0.0688 - val_accuracy: 0.9804 - 5s/epoch - 4ms/step
# Epoch 3/3
# [codecarbon INFO @ 14:06:30] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:06:30] Energy consumed for all GPUs : 0.000133 kWh. Total GPU Power : 32.018976275699764 W
# [codecarbon INFO @ 14:06:30] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:06:30] 0.000331 kWh of electricity used since the beginning.
# 1250/1250 - 5s - loss: 0.0361 - accuracy: 0.9893 - val_loss: 0.0577 - val_accuracy: 0.9836 - 5s/epoch - 4ms/step
# 625/625 - 1s - loss: 0.0577 - accuracy: 0.9836 - 1s/epoch - 2ms/step
# > 98.360
# Epoch 1/3
# 1250/1250 - 7s - loss: 0.1424 - accuracy: 0.9573 - val_loss: 0.0681 - val_accuracy: 0.9808 - 7s/epoch - 5ms/step
# Epoch 2/3
# 1250/1250 - 5s - loss: 0.0521 - accuracy: 0.9837 - val_loss: 0.0622 - val_accuracy: 0.9821 - 5s/epoch - 4ms/step
# Epoch 3/3
# [codecarbon INFO @ 14:06:45] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:06:45] Energy consumed for all GPUs : 0.000266 kWh. Total GPU Power : 31.850785703852754 W
# [codecarbon INFO @ 14:06:45] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:06:45] 0.000660 kWh of electricity used since the beginning.
# 1250/1250 - 5s - loss: 0.0319 - accuracy: 0.9904 - val_loss: 0.0589 - val_accuracy: 0.9826 - 5s/epoch - 4ms/step
# 625/625 - 1s - loss: 0.0589 - accuracy: 0.9826 - 1s/epoch - 2ms/step
# > 98.255
# Epoch 1/3
# 1250/1250 - 6s - loss: 0.1467 - accuracy: 0.9555 - val_loss: 0.0764 - val_accuracy: 0.9755 - 6s/epoch - 5ms/step
# Epoch 2/3
# [codecarbon INFO @ 14:07:00] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:07:00] Energy consumed for all GPUs : 0.000401 kWh. Total GPU Power : 32.39042810456825 W
# [codecarbon INFO @ 14:07:00] Energy consumed for all CPUs : 0.000531 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:07:00] 0.000992 kWh of electricity used since the beginning.
# 1250/1250 - 6s - loss: 0.0533 - accuracy: 0.9842 - val_loss: 0.0720 - val_accuracy: 0.9778 - 6s/epoch - 4ms/step
# Epoch 3/3
# 1250/1250 - 6s - loss: 0.0316 - accuracy: 0.9903 - val_loss: 0.0548 - val_accuracy: 0.9840 - 6s/epoch - 5ms/step
# 625/625 - 1s - loss: 0.0548 - accuracy: 0.9840 - 1s/epoch - 2ms/step
# > 98.400
# Accuracy: mean=98.338 std=0.061, n=3
# [codecarbon INFO @ 14:07:12]
# Graceful stopping: collecting and writing information.
# Please wait a few seconds...
# [codecarbon INFO @ 14:07:12] Energy consumed for RAM : 0.000075 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 14:07:12] Energy consumed for all GPUs : 0.000502 kWh. Total GPU Power : 31.845550147204285 W
# [codecarbon INFO @ 14:07:12] Energy consumed for all CPUs : 0.000667 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 14:07:12] 0.001244 kWh of electricity used since the beginning.
# [codecarbon INFO @ 14:07:12] Done!
