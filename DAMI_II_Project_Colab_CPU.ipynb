# %%
! pip install codecarbon
# Out:
# Collecting codecarbon
#   Downloading codecarbon-2.3.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.0/179.0 kB 1.3 MB/s eta 0:00:00
# Collecting arrow (from codecarbon)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from codecarbon) (1.5.3)
# Collecting pynvml (from codecarbon)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from codecarbon) (2.31.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from codecarbon) (9.0.0)
# Collecting fuzzywuzzy (from codecarbon)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from codecarbon) (8.1.7)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from codecarbon) (0.19.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from arrow->codecarbon) (2.8.2)
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon)
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.16.0)
# Installing collected packages: types-python-dateutil, fuzzywuzzy, pynvml, arrow, codecarbon
# Successfully installed arrow-1.3.0 codecarbon-2.3.2 fuzzywuzzy-0.18.0 pynvml-11.5.0 types-python-dateutil-2.8.19.14

# %%
from numpy import mean
from numpy import std
import keras
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.layers import BatchNormalization
from keras import backend as K
from keras import layers
from codecarbon import track_emissions
import matplotlib.pyplot as plt
import csv

# %%
print(K.backend())
# Out:
# tensorflow

# %%
# cnn model with batch normalization for mnist
# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY

# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm

# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.01, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=3):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=42)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		history = model.fit(trainX, trainY, epochs=3, batch_size=32, validation_data=(testX, testY), verbose=2)
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=2)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories

# plot diagnostic learning curves
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		plt.tight_layout()
		plt.subplot(2, 1, 1)
		plt.grid()
		plt.title('Cross Entropy Loss')
		plt.plot(histories[i].history['loss'], color='darkcyan', label='train')
		plt.plot(histories[i].history['val_loss'], color='violet', label='test')
		handles, labels = plt.gca().get_legend_handles_labels()
		by_label = dict(zip(labels, handles))
		plt.legend(by_label.values(), by_label.keys(),loc="upper right")

		# plot accuracy
		plt.subplot(2, 1, 2)
		plt.grid()
		plt.title('Classification Accuracy')
		plt.plot(histories[i].history['accuracy'], color='darkcyan', label='train')
		plt.plot(histories[i].history['val_accuracy'], color='violet', label='test')
		handles, labels = plt.gca().get_legend_handles_labels()
		by_label = dict(zip(labels, handles))
		plt.legend(by_label.values(), by_label.keys(),loc="lower right")
	plt.show()

# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	plt.boxplot(scores)
	plt.show()

# save model performance to file
def save_performance_to_csv(scores):
	# print summary
	with open ("accuracy_scores_cpu_colab.csv",'a') as f:
		data = ["DAMI II Project Colab CPU TF", round(mean(scores)*100, 3), round(std(scores)*100, 3)]
		writer = csv.writer(f)
		writer.writerow(data)

# run the test harness for evaluating a model

@track_emissions(offline=True, country_iso_code="ITA", project_name = "DAMI II Project Colab CPU TF")
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)
  # print accuracy scores to csv
	save_performance_to_csv(scores)


# run the test harness three times
i=0
while i<3:
	run_test_harness()
	i+=1
# Out:
# [codecarbon INFO @ 15:25:41] offline tracker init
# [codecarbon INFO @ 15:25:41] [setup] RAM Tracking...
# [codecarbon INFO @ 15:25:41] [setup] GPU Tracking...
# [codecarbon INFO @ 15:25:41] No GPU found.
# [codecarbon INFO @ 15:25:41] [setup] CPU Tracking...
# [codecarbon WARNING @ 15:25:41] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 15:25:42] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 15:25:42] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 15:25:42] >>> Tracker's metadata:
# [codecarbon INFO @ 15:25:42]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# [codecarbon INFO @ 15:25:42]   Python version: 3.10.12
# [codecarbon INFO @ 15:25:42]   CodeCarbon version: 2.3.2
# [codecarbon INFO @ 15:25:42]   Available RAM : 12.675 GB
# [codecarbon INFO @ 15:25:42]   CPU count: 2
# [codecarbon INFO @ 15:25:42]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 15:25:42]   GPU count: None
# [codecarbon INFO @ 15:25:42]   GPU model: None
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/3
# [codecarbon INFO @ 15:25:57] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:25:57] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:25:57] 0.000197 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:26:12] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:26:12] Energy consumed for all CPUs : 0.000355 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:26:12] 0.000394 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:26:27] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:26:27] Energy consumed for all CPUs : 0.000532 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:26:27] 0.000591 kWh of electricity used since the beginning.
# 1250/1250 - 46s - loss: 0.1436 - accuracy: 0.9573 - val_loss: 0.0819 - val_accuracy: 0.9751 - 46s/epoch - 37ms/step
# Epoch 2/3
# [codecarbon INFO @ 15:26:42] Energy consumed for RAM : 0.000079 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:26:42] Energy consumed for all CPUs : 0.000709 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:26:42] 0.000788 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:26:57] Energy consumed for RAM : 0.000099 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:26:57] Energy consumed for all CPUs : 0.000886 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:26:57] 0.000985 kWh of electricity used since the beginning.
# 1250/1250 - 32s - loss: 0.0535 - accuracy: 0.9841 - val_loss: 0.0611 - val_accuracy: 0.9819 - 32s/epoch - 25ms/step
# Epoch 3/3
# [codecarbon INFO @ 15:27:12] Energy consumed for RAM : 0.000119 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:27:12] Energy consumed for all CPUs : 0.001063 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:27:12] 0.001182 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:27:27] Energy consumed for RAM : 0.000139 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:27:27] Energy consumed for all CPUs : 0.001240 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:27:27] 0.001379 kWh of electricity used since the beginning.
# 1250/1250 - 31s - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.0618 - val_accuracy: 0.9822 - 31s/epoch - 25ms/step
# 625/625 - 4s - loss: 0.0618 - accuracy: 0.9822 - 4s/epoch - 6ms/step
# > 98.225
# Epoch 1/3
# [codecarbon INFO @ 15:27:42] Energy consumed for RAM : 0.000158 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:27:42] Energy consumed for all CPUs : 0.001417 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:27:42] 0.001576 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:27:57] Energy consumed for RAM : 0.000178 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:27:57] Energy consumed for all CPUs : 0.001594 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:27:57] 0.001773 kWh of electricity used since the beginning.
# 1250/1250 - 35s - loss: 0.1482 - accuracy: 0.9555 - val_loss: 0.0794 - val_accuracy: 0.9774 - 35s/epoch - 28ms/step
# Epoch 2/3
# [codecarbon INFO @ 15:28:12] Energy consumed for RAM : 0.000198 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:28:12] Energy consumed for all CPUs : 0.001771 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:28:12] 0.001969 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:28:27] Energy consumed for RAM : 0.000218 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:28:27] Energy consumed for all CPUs : 0.001949 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:28:27] 0.002167 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:28:42] Energy consumed for RAM : 0.000238 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:28:42] Energy consumed for all CPUs : 0.002126 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:28:42] 0.002363 kWh of electricity used since the beginning.
# 1250/1250 - 33s - loss: 0.0571 - accuracy: 0.9832 - val_loss: 0.0617 - val_accuracy: 0.9820 - 33s/epoch - 26ms/step
# Epoch 3/3
# [codecarbon INFO @ 15:28:57] Energy consumed for RAM : 0.000257 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:28:57] Energy consumed for all CPUs : 0.002303 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:28:57] 0.002560 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:29:12] Energy consumed for RAM : 0.000277 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:29:12] Energy consumed for all CPUs : 0.002480 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:29:12] 0.002757 kWh of electricity used since the beginning.
# 1250/1250 - 31s - loss: 0.0353 - accuracy: 0.9888 - val_loss: 0.0551 - val_accuracy: 0.9838 - 31s/epoch - 25ms/step
# 625/625 - 4s - loss: 0.0551 - accuracy: 0.9838 - 4s/epoch - 6ms/step
# > 98.380
# Epoch 1/3
# [codecarbon INFO @ 15:29:27] Energy consumed for RAM : 0.000297 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:29:27] Energy consumed for all CPUs : 0.002657 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:29:28] 0.002954 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:29:43] Energy consumed for RAM : 0.000317 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:29:43] Energy consumed for all CPUs : 0.002834 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:29:43] 0.003151 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:29:58] Energy consumed for RAM : 0.000337 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:29:58] Energy consumed for all CPUs : 0.003011 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:29:58] 0.003348 kWh of electricity used since the beginning.
# 1250/1250 - 38s - loss: 0.1475 - accuracy: 0.9553 - val_loss: 0.0738 - val_accuracy: 0.9777 - 38s/epoch - 30ms/step
# Epoch 2/3
# [codecarbon INFO @ 15:30:13] Energy consumed for RAM : 0.000356 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:30:13] Energy consumed for all CPUs : 0.003188 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:30:13] 0.003545 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:30:28] Energy consumed for RAM : 0.000376 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:30:28] Energy consumed for all CPUs : 0.003365 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:30:28] 0.003742 kWh of electricity used since the beginning.
# 1250/1250 - 32s - loss: 0.0522 - accuracy: 0.9846 - val_loss: 0.0658 - val_accuracy: 0.9800 - 32s/epoch - 25ms/step
# Epoch 3/3
# [codecarbon INFO @ 15:30:43] Energy consumed for RAM : 0.000396 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:30:43] Energy consumed for all CPUs : 0.003542 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:30:43] 0.003938 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:30:58] Energy consumed for RAM : 0.000416 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:30:58] Energy consumed for all CPUs : 0.003719 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:30:58] 0.004135 kWh of electricity used since the beginning.
# 1250/1250 - 32s - loss: 0.0328 - accuracy: 0.9906 - val_loss: 0.0578 - val_accuracy: 0.9822 - 32s/epoch - 25ms/step
# [codecarbon INFO @ 15:31:13] Energy consumed for RAM : 0.000436 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:31:13] Energy consumed for all CPUs : 0.003896 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:31:13] 0.004332 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:31:28] Energy consumed for RAM : 0.000455 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:31:28] Energy consumed for all CPUs : 0.004073 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:31:28] 0.004529 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:31:43] Energy consumed for RAM : 0.000475 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:31:43] Energy consumed for all CPUs : 0.004250 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:31:43] 0.004725 kWh of electricity used since the beginning.
# 625/625 - 5s - loss: 0.0578 - accuracy: 0.9822 - 5s/epoch - 8ms/step
# > 98.215
# Accuracy: mean=98.273 std=0.076, n=3
# [codecarbon INFO @ 15:31:51]
# Graceful stopping: collecting and writing information.
# Please wait a few seconds...
# [codecarbon INFO @ 15:31:51] Energy consumed for RAM : 0.000487 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:31:51] Energy consumed for all CPUs : 0.004352 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:31:51] 0.004839 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:31:51] Done!
#
# [codecarbon INFO @ 15:31:51] offline tracker init
# [codecarbon INFO @ 15:31:51] [setup] RAM Tracking...
# [codecarbon INFO @ 15:31:51] [setup] GPU Tracking...
# [codecarbon INFO @ 15:31:51] No GPU found.
# [codecarbon INFO @ 15:31:51] [setup] CPU Tracking...
# [codecarbon WARNING @ 15:31:51] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 15:31:53] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 15:31:53] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 15:31:53] >>> Tracker's metadata:
# [codecarbon INFO @ 15:31:53]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# [codecarbon INFO @ 15:31:53]   Python version: 3.10.12
# [codecarbon INFO @ 15:31:53]   CodeCarbon version: 2.3.2
# [codecarbon INFO @
Energy consumed for all CPUs : 0.001063 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:40:51] 0.001181 kWh of electricity used since the beginning.
# 1250/1250 - 31s - loss: 0.0339 - accuracy: 0.9896 - val_loss: 0.0516 - val_accuracy: 0.9849 - 31s/epoch - 25ms/step
# 625/625 - 5s - loss: 0.0516 - accuracy: 0.9849 - 5s/epoch - 8ms/step
# > 98.490
# Epoch 1/3
# [codecarbon INFO @ 15:41:06] Energy consumed for RAM : 0.000139 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:41:06] Energy consumed for all CPUs : 0.001240 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:41:06] 0.001378 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:41:21] Energy consumed for RAM : 0.000158 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:41:21] Energy consumed for all CPUs : 0.001417 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:41:21] 0.001575 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:41:36] Energy consumed for RAM : 0.000178 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:41:36] Energy consumed for all CPUs : 0.001594 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:41:36] 0.001772 kWh of electricity used since the beginning.
# 1250/1250 - 33s - loss: 0.1527 - accuracy: 0.9546 - val_loss: 0.0947 - val_accuracy: 0.9703 - 33s/epoch - 27ms/step
# Epoch 2/3
# [codecarbon INFO @ 15:41:51] Energy consumed for RAM : 0.000198 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:41:51] Energy consumed for all CPUs : 0.001771 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:41:51] 0.001969 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:42:06] Energy consumed for RAM : 0.000218 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:42:06] Energy consumed for all CPUs : 0.001948 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:42:06] 0.002166 kWh of electricity used since the beginning.
# 1250/1250 - 32s - loss: 0.0592 - accuracy: 0.9815 - val_loss: 0.0617 - val_accuracy: 0.9811 - 32s/epoch - 25ms/step
# Epoch 3/3
# [codecarbon INFO @ 15:42:21] Energy consumed for RAM : 0.000238 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:42:21] Energy consumed for all CPUs : 0.002125 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:42:21] 0.002362 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:42:36] Energy consumed for RAM : 0.000257 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:42:36] Energy consumed for all CPUs : 0.002302 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:42:36] 0.002559 kWh of electricity used since the beginning.
# 1250/1250 - 37s - loss: 0.0391 - accuracy: 0.9874 - val_loss: 0.0608 - val_accuracy: 0.9819 - 37s/epoch - 30ms/step
# 625/625 - 4s - loss: 0.0608 - accuracy: 0.9819 - 4s/epoch - 6ms/step
# [codecarbon INFO @ 15:42:51] Energy consumed for RAM : 0.000277 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:42:51] Energy consumed for all CPUs : 0.002479 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:42:51] 0.002756 kWh of electricity used since the beginning.
# > 98.190
# Epoch 1/3
# [codecarbon INFO @ 15:43:06] Energy consumed for RAM : 0.000297 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:43:06] Energy consumed for all CPUs : 0.002656 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:43:06] 0.002953 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:43:21] Energy consumed for RAM : 0.000317 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:43:21] Energy consumed for all CPUs : 0.002833 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:43:21] 0.003150 kWh of electricity used since the beginning.
# 1250/1250 - 33s - loss: 0.1399 - accuracy: 0.9585 - val_loss: 0.0717 - val_accuracy: 0.9782 - 33s/epoch - 27ms/step
# Epoch 2/3
# [codecarbon INFO @ 15:43:36] Energy consumed for RAM : 0.000337 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:43:36] Energy consumed for all CPUs : 0.003010 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:43:36] 0.003347 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:43:51] Energy consumed for RAM : 0.000356 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:43:51] Energy consumed for all CPUs : 0.003187 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:43:51] 0.003544 kWh of electricity used since the beginning.
# 1250/1250 - 31s - loss: 0.0530 - accuracy: 0.9835 - val_loss: 0.0614 - val_accuracy: 0.9815 - 31s/epoch - 25ms/step
# Epoch 3/3
# [codecarbon INFO @ 15:44:06] Energy consumed for RAM : 0.000376 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:44:06] Energy consumed for all CPUs : 0.003364 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:44:06] 0.003741 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:44:21] Energy consumed for RAM : 0.000396 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:44:21] Energy consumed for all CPUs : 0.003541 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:44:21] 0.003937 kWh of electricity used since the beginning.
# 1250/1250 - 30s - loss: 0.0315 - accuracy: 0.9908 - val_loss: 0.0567 - val_accuracy: 0.9823 - 30s/epoch - 24ms/step
# 625/625 - 6s - loss: 0.0567 - accuracy: 0.9823 - 6s/epoch - 10ms/step
# > 98.235
# Accuracy: mean=98.305 std=0.132, n=3
# [codecarbon INFO @ 15:44:34]
# Graceful stopping: collecting and writing information.
# Please wait a few seconds...
# [codecarbon INFO @ 15:44:34] Energy consumed for RAM : 0.000413 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 15:44:34] Energy consumed for all CPUs : 0.003695 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:44:34] 0.004108 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:44:34] Done!
